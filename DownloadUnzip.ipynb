# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Create a directory to store the dataset
dataset_dir = '/content/drive/My Drive/datasets'
#os.makedirs(dataset_dir, exist_ok=True)

# Change the current directory to the dataset directory
os.chdir(dataset_dir)

# %%
# !wget https://zenodo.org/records/4003541/files/01-InHARD.7z.001?download=1
# Out:
# --2024-02-28 04:01:32--  https://zenodo.org/records/4003541/files/01-InHARD.7z.001?download=1
# Resolving zenodo.org (zenodo.org)... 188.184.98.238, 188.184.103.159, 188.185.79.172, ...
# Connecting to zenodo.org (zenodo.org)|188.184.98.238|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4290772992 (4.0G) [application/octet-stream]
# Saving to: ‘01-InHARD.7z.001?download=1.1’
#
# 01-InHARD.7z.001?do 100%[===================>]   4.00G  16.5MB/s    in 4m 1s
#
# 2024-02-28 04:05:34 (17.0 MB/s) - ‘01-InHARD.7z.001?download=1.1’ saved [4290772992/4290772992]

# %%
# !ls Segmented/RGBSegmented
# Out:
# 'Assemble system'  'Picking in front'	     'Put down screwdriver'  'Take screwdriver'
#  a.txt		   'Picking left'	     'Put down subsystem'    'Take subsystem'
# 'Consult sheets'   'Put down component'      'Take component'	     'Turn sheets'
# 'No action'	   'Put down measuring rod'  'Take measuring rod'

# %%
!7za x 01-InHARD.7z.001
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 4290772992 bytes (4092 MiB)
#
# Extracting archive: 01-InHARD.7z.001
# --
# Path = 01-InHARD.7z.001
# Type = Split
# Physical Size = 4290772992
# Volumes = 12
# Total Physical Size = 50046610145
# ----
# Path = 01-InHARD.7z
# Size = 50046610145
# --
# Path = 01-InHARD.7z
# Type = 7z
# Physical Size = 50046610145
# Headers Size = 139886
# Method = LZMA2:25
# Solid = +
# Blocks = 25
#
# Everything is Ok
#
# Folders: 38
# Files: 10778
# Size:       60585927970
# Compressed: 50046610145
